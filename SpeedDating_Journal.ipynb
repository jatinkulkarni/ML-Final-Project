# %% [markdown]
# # Names: Ryan Murray, Gbemiga Oyenubi, Jatin Kulkarni, and Andrew White

# %% [markdown]
# # Project 1: (INSERT A TITLE HERE FOR THE DATASET)
# (INSET SOME WORDS HERE ABOUT THE STUFF WE'LL BE LOOKING AT AND HOW WE WILL BE DOING THOSE OBSERVATIONS AND OUR END GOAL)

# %%
'''
        TODO LIST
🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
TODO: Specify the types of values in each column
TODO: Group certain features and do work on those groups
TODO: IDK.. Probably LOTS of shit
🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥
'''

# %%
# Some Normal Imports "Of Course"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
# Enable inline mode for matplotlib so that IPython displays graphs
# %matplotlib inline

# %%
# Porting in the data from the csv file
full_dating = pd.read_csv("SpeedDating.csv")
print(full_dating.shape)
full_dating.head()
# Out:
# (8378, 124)
# age
# /var/folders/vh/nd13302161s86xf0fyck6r5m0000gn/T/ipykernel_6099/2075674503.py:2: DtypeWarning: Columns (4,11,12,16,17,18,19,20,40,41,42,43,44,45,52,53,54,55,56,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,108,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_dating = pd.read_csv("SpeedDating.csv")
#    id  has_null  wave  gender age age_o  d_age d_d_age  \
# 0   1         0     1  female  21    27      6   [4-6]
# 1   2         0     1  female  21    22      1   [0-1]
# 2   3         1     1  female  21    22      1   [0-1]
# 3   4         0     1  female  21    23      2   [2-3]
# 4   5         0     1  female  21    24      3   [2-3]
#
#                                     race  \
# 0  Asian/Pacific Islander/Asian-American
# 1  Asian/Pacific Islander/Asian-American
# 2  Asian/Pacific Islander/Asian-American
# 3  Asian/Pacific Islander/Asian-American
# 4  Asian/Pacific Islander/Asian-American
#
# ...
